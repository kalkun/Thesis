# %% [markdown]
# ## UCLA model trained on the combined ITU + UCLA dataset without visual attributes without any score preprocessing evaluation

# %%
import os
import pandas as pd
from lib import analysis_utils as au
import matplotlib.pyplot as plt
import scipy
import numpy as np
# Out:
# /home/lucas/Documents/ITU/Thesis_2018/venv/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ### Load the data

# %%
pred_dir = "models_preds"
file_name = "UCLA_model_without_visual_in_combined_dataset_no_score_preprocessing_datalen-44446_epochs-100_init_lr-0.01_momentum-0.9_batch_size-32_n_folds-5_n_folds_seed-300.csv"
preds = pd.read_csv(os.path.join(pred_dir, file_name))
        
print ("loaded ", len(preds), " rows")
# Out:
# loaded  8888  rows

# %%
preds
# Out:
#              imageHASH                   name  violence  protest  luca rossi  \
# 0     54dbf81c39596068        train-18661.jpg  0.155881     True       False
# 1     b36dd1b331bb2baa        train-30229.jpg  0.112239     True       False
# 2     64c444099a5475c5        train-13975.jpg  0.183749     True       False
# 3     2e1ce862ceca8aaa        train-11855.jpg  0.136725     True       False
# 4     7332acacbea4e62a        train-24927.jpg -1.000000    False       False
# 5     9b9d0d0a0ad9696d        train-07854.jpg  0.180580     True       False
# 6     63cf33534b086c20        train-12823.jpg -1.000000    False       False
# 7     f864f0f66e623636         test-05258.jpg  0.220342     True       False
# 8     92b048c6a4c8aaac        train-24408.jpg -1.000000    False       False
# 9     f1f3a3aaa2021230        train-28415.jpg -1.000000    False       False
# 10    b53335373f393a32        train-15857.jpg -1.000000    False       False
# 11    a6a64cdc905a595d        train-06143.jpg -1.000000    False       False
# 12    69b331317395b9d6         test-01029.jpg  0.255946     True       False
# 13    79f8aee4bc2c6ccd        train-31198.jpg  0.129932     True       False
# 14    566e6e133a41c666        train-23676.jpg -1.000000    False       False
# 15    b1a3e3ceccf4ee92        train-09528.jpg -1.000000    False       False
# 16    d2d2c2c9d0f0b0e4         test-02113.jpg -1.000000    False       False
# 17    0199983a3a3a6063        train-04977.jpg -1.000000    False       False
# 18    4d0f5656332b071d        train-19296.jpg  0.158563     True       False
# 19    9ebbc765ae5496ae        train-25800.jpg  0.279849     True       False
# 20    071787cf47464e2d         test-05648.jpg  0.260874     True       False
# 21    98a46d2da4a41d75        train-20344.jpg -1.000000    False       False
# 22    6375715127213131        train-15097.jpg -1.000000    False       False
# 23    5935f4f634321b5d        train-11710.jpg -1.000000    False       False
# 24    e8d8d89898996d34        train-04765.jpg -1.000000    False       False
# 25    ccda5bc747717b58        train-17490.jpg -1.000000    False       False
# 26    f0f2d098c2f6a641        train-18762.jpg  0.329462     True       False
# 27    96e46933b3a0e8e8        train-23231.jpg -1.000000    False       False
# 28    69e0a6ce9b8dc8c6        train-08348.jpg  0.108385     True       False
# 29    3939061633139313        train-22981.jpg -1.000000    False       False
# ...                ...                    ...       ...      ...         ...
# 8858  9c9ea4f0c8d6960c        train-19944.jpg -1.000000    False       False
# 8859  335b533433338843        train-19938.jpg -1.000000    False       False
# 8860  4f0685316860632c        train-24946.jpg -1.000000    False       False
# 8861  0023329db236a500        train-14892.jpg -1.000000    False       False
# 8862  e4e2504c5651296d        train-17316.jpg -1.000000    False       False
# 8863  d0acb8b236e4f2f6         test-06446.jpg -1.000000    False       False
# 8864  11aa199d4d852724         test-07093.jpg  0.091533     True       False
# 8865  cfc9b1a676367663         test-04618.jpg  0.247825     True       False
# 8866  b6c53b6b4d9bdb86        train-18421.jpg  0.062407     True       False
# 8867  d05848605935959d        train-27025.jpg  0.196908     True       False
# 8868  e5b1b0c661898547        train-25560.jpg  0.146496     True       False
# 8869  7b636343238f91b0        train-09396.jpg -1.000000    False       False
# 8870  332363892c33d3f5        train-07423.jpg -1.000000    False       False
# 8871  8e0e8ededf198d09  8e0e8ededf198d09.jpeg  0.067849     True        True
# 8872  98989989c86465e8        train-31323.jpg  0.122056     True       False
# 8873  1c949c9c2434c4c4        train-10816.jpg  0.129077     True       False
# 8874  9f2f323490386d6b        train-32030.jpg  0.154285     True       False
# 8875  d2122a7236361636        train-07099.jpg -1.000000    False       False
# 8876  9ed4666de9d98c4c         test-06256.jpg  0.098470     True       False
# 8877  914084992cfcd958        train-07195.jpg  0.125244     True       False
# 8878  239332b39a2426ca  239332b39a2426ca.jpeg -1.000000    False        True
# 8879  dc5c3c342a3ee092        train-20536.jpg -1.000000    False       False
# 8880  89b929b8d01078f0  89b929b8d01078f0.jpeg -1.000000    False        True
# 8881  a9a56c66767289d2        train-06932.jpg -1.000000    False       False
# 8882  7448e4f0b369b89a        train-09059.jpg -1.000000    False       False
# 8883  860859730f21c200         test-04454.jpg -1.000000    False       False
# 8884  9f5d494f24448c86        train-08564.jpg  0.247771     True       False
# 8885  20a686aca4cd9d96  20a686aca4cd9d96.jpeg  0.126234     True        True
# 8886  e8ec9e7fcec64381        train-25017.jpg  0.157661     True       False
# 8887  cbebebd79796d4ec        train-05486.jpg -1.000000    False       False
#
#       pred_protest  pred_violence
# 0     9.918880e-01       0.136420
# 1     9.947219e-01       0.128848
# 2     6.103869e-01       0.211644
# 3     9.999392e-01       0.144303
# 4     1.381314e-01       0.234751
# 5     9.982129e-01       0.144553
# 6     2.958899e-03       0.088580
# 7     6.404966e-01       0.172134
# 8     7.744023e-04       0.131150
# 9     4.135717e-01       0.182873
# 10    5.443382e-02       0.195217
# 11    8.969136e-02       0.086054
# 12    8.527368e-01       0.222879
# 13    9.974639e-01       0.175978
# 14    9.400243e-03       0.128539
# 15    6.490321e-01       0.208649
# 16    1.306559e-01       0.149055
# 17    4.704434e-03       0.032952
# 18    9.876795e-01       0.166522
# 19    3.754854e-01       0.309111
# 20    9.315864e-01       0.282591
# 21    7.359260e-05       0.054454
# 22    2.344474e-03       0.158077
# 23    2.651689e-07       0.027795
# 24    8.631257e-07       0.050237
# 25    2.021360e-02       0.066917
# 26    3.263122e-01       0.313682
# 27    3.324749e-04       0.091118
# 28    9.926736e-01       0.135990
# 29    2.928043e-03       0.075318
# ...            ...            ...
# 8858  2.740991e-05       0.086458
# 8859  1.505607e-02       0.118121
# 8860  3.119490e-01       0.139787
# 8861  2.566910e-02       0.099107
# 8862  2.097417e-05       0.065925
# 8863  1.921636e-01       0.257644
# 8864  9.986402e-01       0.122593
# 8865  7.576888e-01       0.206131
# 8866  1.472791e-01       0.121585
# 8867  8.129470e-01       0.217194
# 8868  7.581114e-01       0.183569
# 8869  3.313823e-02       0.164048
# 8870  7.237593e-04       0.124254
# 8871  2.695715e-01       0.128398
# 8872  9.987844e-01       0.139659
# 8873  6.886209e-01       0.221412
# 8874  8.736484e-01       0.123727
# 8875  2.208515e-04       0.070691
# 8876  9.922292e-01       0.146731
# 8877  9.995449e-01       0.146254
# 8878  5.263151e-02       0.117634
# 8879  3.336099e-01       0.276776
# 8880  4.576191e-01       0.220632
# 8881  9.275231e-05       0.094184
# 8882  9.292092e-04       0.135548
# 8883  7.383935e-03       0.075123
# 8884  2.010092e-01       0.269729
# 8885  9.652766e-01       0.178926
# 8886  9.464010e-01       0.157056
# 8887  1.500858e-04       0.055668
#
# [8888 rows x 7 columns]

# %% [markdown]
# ### Protest

# %%
au.plotROC("protest", preds["protest"], preds["pred_protest"])

# %% [markdown]
# ### Violence

# %%
# remove masked values from test set
non_masked_violence_true = preds[preds["violence"] != - 1]["violence"]
non_masked_violence_preds = preds[preds["violence"] != - 1]["pred_violence"]

fig, ax = plt.subplots()
plt.scatter(non_masked_violence_true, non_masked_violence_preds, label = "violence")
plt.xlim([-.05,1.05])
plt.ylim([-.05,1.05])
plt.xlabel('Annotation', fontsize = 15)
plt.ylabel('Predicton', fontsize = 15)
corr, pval = scipy.stats.pearsonr(non_masked_violence_true, non_masked_violence_preds)
slope, intercept, r_value, p_value, std_err = scipy.stats.linregress(non_masked_violence_true,non_masked_violence_preds)
r_squared = r_value ** 2
plt.title(('{attr} (Correlation = {corr:.3f}, R_squared = {r_2:.3f} )'
            .format(attr = "violence", corr= corr, r_2 = r_squared)), fontsize = 15)
# Out:
# Text(0.5,1,'violence (Correlation = 0.781, R_squared = 0.610 )')
