# %% [markdown]
# ## UCLA model trained on the UCLA dataset without visual attributes evaluation

# %%
import sys
sys.path.append("../../venv/lib/python3.6/site-packages/")
sys.path.append("..")

# %%
import os
import pandas as pd
from lib import analysis_utils as au
import matplotlib.pyplot as plt
import scipy
import numpy as np
# Out:
# /home/jesper/tmp/venv/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ### Load the data

# %%
pred_dir = "models_preds"
# file_name = "UCLA_model_UCLA_dataset_without_visual_attributes_datalen-40720_epochs-100_init_lr-0.01_momentum-0.9_batch_size-32_n_folds-5_n_folds_seed-300.csv"
file_name = 'fully_con_reduced_transform_without_protest_datalen-11646_epochs-100_init_lr-0.01_momentum-0.9_batch_size-32_n_folds-5_n_folds_seed-300.csv'
preds = pd.read_csv(os.path.join(pred_dir, file_name))
        
print ("loaded ", len(preds), " rows")
# Out:
# loaded  2329  rows

# %%
preds
# Out:
#              imageHASH             name  violence   sign  photo   fire  \
# 0     7630e8e8a2366464   test-01339.jpg  0.339361   True  False  False
# 1     98d8cc2a30e4c2c2  train-23444.jpg  0.267467   True  False  False
# 2     240d99f8e87b374c  train-21504.jpg  0.261983   True  False  False
# 3     d69272662b3d7cb6   test-04018.jpg  0.368959   True   True  False
# 4     9832a4e1f09abeac  train-14452.jpg  0.205163   True  False  False
# 5     f5bd5c54db929692  train-28689.jpg  0.350273  False  False  False
# 6     c9698b2b869e96ec  train-30511.jpg  0.322933   True  False  False
# 7     4c7cf4946e62e4e0  train-12885.jpg  0.206890   True  False  False
# 8     8d090d5d79b39296   test-06908.jpg  0.316481   True  False  False
# 9     a5a785c7ced6cfc7  train-23820.jpg  0.299302   True  False  False
# 10    38185873874e5bdb  train-07432.jpg  0.306340   True  False  False
# 11    a0cacdbd52a99ad8  train-02531.jpg  0.331894  False  False  False
# 12    c3e2465414b3a72d  train-32384.jpg  0.468924   True  False  False
# 13    a18fc6e44b4d95e5  train-28782.jpg  0.311695   True  False  False
# 14    9ab4accd3353e0b6   test-02355.jpg  0.531336  False   True  False
# 15    18ced6d6cce8c297  train-30264.jpg  0.140483   True  False  False
# 16    7753d35272727273  train-30290.jpg  0.277027   True  False  False
# 17    04442e61a901d989  train-27855.jpg  0.122635   True  False  False
# 18    6a72f39691e0f214   test-07787.jpg  0.299311   True  False  False
# 19    bb084d26a2736464  train-16182.jpg  0.546793   True  False  False
# 20    d4d8b93539a9859c   test-05319.jpg  0.285261   True  False  False
# 21    e1f59988448e9f8d  train-28754.jpg  0.337613  False  False  False
# 22    6626a5c2833d7fff  train-00862.jpg  0.455171   True  False  False
# 23    cfcfe0f2bc8565ef  train-10374.jpg  0.326846   True  False  False
# 24    256163d4e567a2a2  train-09919.jpg  0.491303   True  False  False
# 25    846020eeba4f0f6b   test-06670.jpg  0.381514   True  False  False
# 26    e0b0d4d2b6c2421a  train-03641.jpg  0.380534   True  False  False
# 27    8ed2d1ccd894e4c8  train-28362.jpg  0.081493   True  False  False
# 28    a5c5e1a161c9c8e8  train-09520.jpg  0.341215   True   True  False
# 29    e4e4ead393b2d39b  train-10177.jpg  0.213024   True  False  False
# ...                ...              ...       ...    ...    ...    ...
# 2299  e1da0c1093cbe32b   test-03152.jpg  0.403053   True  False  False
# 2300  a63cd8e0a486acc3  train-14600.jpg  0.180584   True  False  False
# 2301  9a98d0943c3e3e3e  train-04266.jpg  0.642194  False  False   True
# 2302  f0e00698cc862c1c  train-07434.jpg  0.420783   True  False  False
# 2303  d3f87b3ddedcb978  train-14939.jpg  0.346866   True  False  False
# 2304  a4acab2b96d74125  train-00644.jpg  0.442660  False  False  False
# 2305  ccc465c3c7193d35   test-01100.jpg  0.335121   True  False  False
# 2306  40b0be68cccd9ad9  train-28652.jpg  0.317234   True  False  False
# 2307  2931b52b1b3cfce9   test-06516.jpg  0.358596   True   True  False
# 2308  9b9d0d0a0ad9696d  train-07854.jpg  0.419953   True   True  False
# 2309  383c796bcbcc4c5c  train-31101.jpg  0.215230   True  False  False
# 2310  821ba78cc9e9495d  train-12956.jpg  0.593585   True  False  False
# 2311  b4fce4cc8a9a8a0e  train-15280.jpg  0.284625   True  False  False
# 2312  ca626a6b4b5c2c2c  train-26617.jpg  0.546385  False  False  False
# 2313  a48a90d4d2b2b4b4  train-08913.jpg  0.400550   True  False  False
# 2314  3157539bda4e9b3a  train-03484.jpg  0.360915   True  False  False
# 2315  94b2da16368686b7  train-17797.jpg  0.402353  False  False  False
# 2316  f0f2d098c2f6a641  train-18762.jpg  0.766190  False  False   True
# 2317  9811a1c850393d9d  train-24354.jpg  0.566891   True  False  False
# 2318  1191d5e5cdade5b4   test-07164.jpg  0.453419   True  False  False
# 2319  b098901065cc869b  train-01873.jpg  0.273543   True  False  False
# 2320  ccd8d8ccdcdcf4e8  train-26644.jpg  0.184124   True  False  False
# 2321  337fd7150f03018b  train-09231.jpg  0.414903   True  False  False
# 2322  0c680f2479657131  train-23628.jpg  0.297591  False  False  False
# 2323  74f16a507676747c   test-07109.jpg  0.411054  False  False  False
# 2324  291c3e6f93317a6a  train-21556.jpg  0.390253   True  False  False
# 2325  4ac8c1d979793931  train-19544.jpg  0.225057   True  False  False
# 2326  333b455c29a9c94d  train-29473.jpg  0.283542   True  False  False
# 2327  f0e1245db4e4dcd6  train-28390.jpg  0.495314  False  False  False
# 2328  8c8ee671f9d8c471  train-21695.jpg  0.391909   True  False  False
#
#       police  children  group_20  group_100      ...        pred_sign  \
# 0      False     False      True      False      ...         0.788648
# 1      False     False      True      False      ...         0.904361
# 2      False     False      True      False      ...         0.976835
# 3      False     False      True      False      ...         0.940968
# 4      False      True      True      False      ...         0.908464
# 5      False     False     False      False      ...         0.726340
# 6      False     False     False      False      ...         0.796513
# 7      False     False     False      False      ...         0.998950
# 8      False     False      True      False      ...         0.939360
# 9      False     False     False      False      ...         0.987622
# 10     False     False     False      False      ...         0.368890
# 11     False     False      True       True      ...         0.829982
# 12     False     False      True       True      ...         0.986962
# 13     False     False      True      False      ...         0.959592
# 14     False     False      True       True      ...         0.889080
# 15     False     False     False      False      ...         0.995731
# 16     False     False     False      False      ...         0.952833
# 17     False     False     False      False      ...         0.976967
# 18     False     False      True       True      ...         0.990234
# 19     False     False      True      False      ...         0.198757
# 20     False     False     False      False      ...         0.987744
# 21     False     False      True      False      ...         0.769172
# 22     False     False      True      False      ...         0.803047
# 23     False     False      True      False      ...         0.960256
# 24     False     False      True      False      ...         0.972159
# 25     False     False      True       True      ...         0.767575
# 26     False     False      True      False      ...         0.837612
# 27     False      True     False      False      ...         0.999306
# 28     False     False      True      False      ...         0.993079
# 29     False     False      True      False      ...         0.999748
# ...      ...       ...       ...        ...      ...              ...
# 2299   False     False      True      False      ...         0.974978
# 2300   False     False     False      False      ...         0.994958
# 2301   False     False      True      False      ...         0.356251
# 2302   False     False      True       True      ...         0.895412
# 2303   False     False      True       True      ...         0.988045
# 2304    True     False     False      False      ...         0.382670
# 2305   False     False      True      False      ...         0.882042
# 2306   False     False      True      False      ...         0.950179
# 2307   False     False      True       True      ...         0.973018
# 2308   False     False      True      False      ...         0.931698
# 2309   False     False     False      False      ...         0.978313
# 2310    True     False      True      False      ...         0.547651
# 2311   False     False      True      False      ...         0.917515
# 2312   False      True     False      False      ...         0.082275
# 2313   False     False     False      False      ...         0.976361
# 2314   False     False      True      False      ...         0.960682
# 2315   False     False      True       True      ...         0.970284
# 2316   False     False      True       True      ...         0.111640
# 2317   False     False      True       True      ...         0.746602
# 2318   False     False      True       True      ...         0.962435
# 2319   False     False      True      False      ...         0.997999
# 2320   False     False     False      False      ...         0.978387
# 2321   False     False      True      False      ...         0.711720
# 2322   False     False      True      False      ...         0.911316
# 2323   False     False     False      False      ...         0.344197
# 2324   False     False      True      False      ...         0.988254
# 2325   False     False      True      False      ...         0.998693
# 2326   False     False      True      False      ...         0.783751
# 2327   False     False      True       True      ...         0.657847
# 2328   False     False      True      False      ...         0.993508
#
#       pred_photo  pred_fire  pred_police  pred_children  pred_group_20  \
# 0       0.045952   0.001491     0.018132       0.010560       0.922547
# 1       0.052632   0.002538     0.037236       0.009460       0.910955
# 2       0.005229   0.001441     0.004906       0.003013       0.835217
# 3       0.042704   0.000447     0.005871       0.010519       0.987368
# 4       0.028560   0.000192     0.002949       0.031645       0.943137
# 5       0.069698   0.005252     0.017424       0.026593       0.833265
# 6       0.011298   0.004737     0.031870       0.024952       0.517843
# 7       0.023418   0.000048     0.000295       0.025299       0.453468
# 8       0.008610   0.000443     0.001913       0.004715       0.861029
# 9       0.010487   0.000157     0.001511       0.008923       0.682204
# 10      0.012572   0.094291     0.224575       0.007473       0.618647
# 11      0.032810   0.012678     0.032161       0.004226       0.902608
# 12      0.060844   0.003216     0.010737       0.016129       0.891559
# 13      0.026807   0.000683     0.002056       0.018968       0.886392
# 14      0.023055   0.003704     0.008898       0.001614       0.990720
# 15      0.097651   0.000277     0.001270       0.014006       0.460642
# 16      0.025757   0.002179     0.009604       0.015083       0.410948
# 17      0.013400   0.002121     0.008817       0.021489       0.266924
# 18      0.066216   0.001605     0.005804       0.013520       0.920545
# 19      0.010442   0.054191     0.225350       0.004553       0.693483
# 20      0.038988   0.000612     0.001989       0.022050       0.487354
# 21      0.035576   0.000914     0.009941       0.013592       0.968102
# 22      0.061468   0.009017     0.046500       0.051594       0.921525
# 23      0.047853   0.000666     0.003203       0.044005       0.750205
# 24      0.036359   0.000925     0.032746       0.019795       0.954428
# 25      0.015873   0.000850     0.006012       0.010614       0.983068
# 26      0.012374   0.000081     0.001056       0.025190       0.951981
# 27      0.006510   0.000059     0.000269       0.029404       0.157651
# 28      0.072116   0.000331     0.001744       0.031715       0.694525
# 29      0.021638   0.000024     0.000171       0.002163       0.915152
# ...          ...        ...          ...            ...            ...
# 2299    0.048234   0.001327     0.005934       0.019031       0.940853
# 2300    0.010795   0.000321     0.001626       0.014021       0.382706
# 2301    0.010763   0.601228     0.118869       0.019225       0.435520
# 2302    0.047166   0.005303     0.026145       0.007393       0.880837
# 2303    0.090984   0.000712     0.003244       0.018473       0.923834
# 2304    0.018250   0.024310     0.074281       0.013412       0.818655
# 2305    0.015758   0.001201     0.007516       0.021590       0.938424
# 2306    0.029579   0.000715     0.002396       0.015885       0.837816
# 2307    0.017157   0.000376     0.005319       0.054825       0.762015
# 2308    0.110226   0.001928     0.007867       0.023835       0.940764
# 2309    0.038655   0.000458     0.004157       0.038043       0.667819
# 2310    0.043098   0.231118     0.305606       0.064181       0.863511
# 2311    0.017741   0.000835     0.002409       0.004995       0.898291
# 2312    0.001333   0.007314     0.796229       0.006243       0.668539
# 2313    0.120896   0.000748     0.001044       0.021640       0.653768
# 2314    0.031052   0.001708     0.006004       0.009989       0.839428
# 2315    0.011926   0.000074     0.000493       0.000459       0.997100
# 2316    0.007495   0.985034     0.410477       0.004832       0.741535
# 2317    0.046242   0.007352     0.063647       0.033425       0.939807
# 2318    0.012689   0.000119     0.001759       0.001778       0.994232
# 2319    0.020619   0.000288     0.001741       0.001822       0.880677
# 2320    0.005475   0.006462     0.012360       0.051324       0.328668
# 2321    0.051746   0.007098     0.014158       0.032430       0.874505
# 2322    0.118081   0.001458     0.010771       0.011413       0.964588
# 2323    0.032484   0.011298     0.081045       0.044014       0.665459
# 2324    0.028646   0.003252     0.007954       0.006354       0.866017
# 2325    0.027615   0.000089     0.000303       0.026121       0.330895
# 2326    0.035233   0.001340     0.004022       0.008472       0.909295
# 2327    0.009711   0.000999     0.006644       0.002360       0.981234
# 2328    0.034962   0.000458     0.007414       0.008549       0.967483
#
#       pred_group_100  pred_flag  pred_night  pred_shouting
# 0           0.466691   0.034654    0.346491       0.238260
# 1           0.219080   0.120947    0.023363       0.078450
# 2           0.172503   0.013041    0.085274       0.005741
# 3           0.590899   0.076310    0.002887       0.147191
# 4           0.226500   0.028434    0.000372       0.096147
# 5           0.126897   0.142111    0.006760       0.337044
# 6           0.010071   0.042129    0.008942       0.022905
# 7           0.012918   0.001597    0.004436       0.013244
# 8           0.217832   0.006013    0.032432       0.005256
# 9           0.030912   0.010710    0.008126       0.041858
# 10          0.063740   0.083914    0.305451       0.051252
# 11          0.725529   0.054156    0.778053       0.025885
# 12          0.560447   0.070057    0.286840       0.104769
# 13          0.213254   0.017404    0.003628       0.051491
# 14          0.873867   0.140348    0.020040       0.013687
# 15          0.019519   0.061216    0.001718       0.009464
# 16          0.027217   0.014150    0.078121       0.048318
# 17          0.008216   0.013359    0.011132       0.012576
# 18          0.429598   0.085740    0.003889       0.124093
# 19          0.116305   0.020776    0.834856       0.117180
# 20          0.016356   0.123909    0.002268       0.080068
# 21          0.400478   0.068205    0.006047       0.052457
# 22          0.436583   0.149100    0.014467       0.078253
# 23          0.137200   0.013225    0.010941       0.021761
# 24          0.324737   0.033479    0.003969       0.172690
# 25          0.544875   0.109456    0.001049       0.035767
# 26          0.378332   0.004091    0.001540       0.142334
# 27          0.013113   0.000726    0.039922       0.001507
# 28          0.039269   0.022259    0.001521       0.028720
# 29          0.019520   0.003550    0.001732       0.085826
# ...              ...        ...         ...            ...
# 2299        0.387539   0.261406    0.001786       0.093695
# 2300        0.023169   0.008852    0.016422       0.007337
# 2301        0.029604   0.062874    0.049537       0.023842
# 2302        0.360145   0.085181    0.087350       0.088673
# 2303        0.415550   0.055660    0.039867       0.147145
# 2304        0.101727   0.127393    0.098150       0.151121
# 2305        0.439712   0.035064    0.006166       0.008353
# 2306        0.157651   0.058600    0.005371       0.062180
# 2307        0.071054   0.024071    0.005222       0.066139
# 2308        0.459332   0.067823    0.004632       0.089304
# 2309        0.060389   0.058772    0.003338       0.040162
# 2310        0.165223   0.167220    0.014426       0.117866
# 2311        0.229630   0.019923    0.010282       0.037846
# 2312        0.010334   0.047728    0.001682       0.061177
# 2313        0.025926   0.010493    0.007132       0.230192
# 2314        0.076210   0.607695    0.001939       0.060092
# 2315        0.904640   0.072109    0.002370       0.014952
# 2316        0.063071   0.019269    0.061563       0.013352
# 2317        0.398119   0.314186    0.008248       0.177911
# 2318        0.837240   0.072733    0.002487       0.010028
# 2319        0.131491   0.018790    0.339678       0.029732
# 2320        0.015743   0.014733    0.008347       0.009904
# 2321        0.415835   0.153591    0.009285       0.054410
# 2322        0.626509   0.083932    0.016706       0.108106
# 2323        0.057800   0.047701    0.011605       0.160884
# 2324        0.142386   0.045455    0.261734       0.071964
# 2325        0.003033   0.004884    0.001274       0.002919
# 2326        0.337270   0.028736    0.013489       0.030591
# 2327        0.774111   0.051267    0.008984       0.018365
# 2328        0.437575   0.199190    0.002473       0.121789
#
# [2329 rows x 24 columns]

# %% [markdown]
# ### Protest

# %%
# au.plotROC("protest", preds["protest"], preds["pred_protest"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/tmp/venv/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'protest'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-6bfdb52dc966> in <module>()
# ----> 1 au.plotROC("protest", preds["protest"], preds["pred_protest"])
#
# ~/tmp/venv/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# ~/tmp/venv/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# ~/tmp/venv/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# ~/tmp/venv/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~/tmp/venv/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'protest'

# %% [markdown]
# ### Violence

# %%
# remove masked values from test set
non_masked_violence_true = preds[preds["violence"] != - 1]["violence"]
non_masked_violence_preds = preds[preds["violence"] != - 1]["pred_violence"]

fig, ax = plt.subplots()
plt.scatter(non_masked_violence_true, non_masked_violence_preds, label = "violence")
plt.xlim([-.05,1.05])
plt.ylim([-.05,1.05])
plt.xlabel('Annotation', fontsize = 15)
plt.ylabel('Predicton', fontsize = 15)
corr, pval = scipy.stats.pearsonr(non_masked_violence_true, non_masked_violence_preds)
slope, intercept, r_value, p_value, std_err = scipy.stats.linregress(non_masked_violence_true,non_masked_violence_preds)
r_squared = r_value ** 2
plt.title(('{attr} (Correlation = {corr:.3f}, R_squared = {r_2:.3f} )'
            .format(attr = "violence", corr= corr, r_2 = r_squared)), fontsize = 15)
