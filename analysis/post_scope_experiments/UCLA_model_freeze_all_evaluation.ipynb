# %% [markdown]
# ## UCLA model trained on the UCLA dataset without visual attributes evaluation

# %%
import sys
sys.path.append("../../venv/lib/python3.6/site-packages/")
sys.path.append("..")

# %%
import os
import pandas as pd
from lib import analysis_utils as au
import matplotlib.pyplot as plt
import scipy
import numpy as np
# Out:
# /home/jesper/tmp/venv/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ### Load the data

# %%
pred_dir = "models_preds"
# file_name = "UCLA_model_UCLA_dataset_without_visual_attributes_datalen-40720_epochs-100_init_lr-0.01_momentum-0.9_batch_size-32_n_folds-5_n_folds_seed-300.csv"
file_name = 'UCLA_model_freeze_all_datalen-40720_epochs-100_init_lr-0.01_momentum-0.9_batch_size-32_n_folds-5_n_folds_seed-300.csv'
preds = pd.read_csv(os.path.join(pred_dir, file_name))
        
print ("loaded ", len(preds), " rows")
# Out:
# loaded  8143  rows

# %%
preds
# Out:
#              imageHASH             name  violence  protest  pred_protest  \
# 0     64adf672a10584f0  train-15308.jpg  0.415880     True      0.026396
# 1     f829656d1b626745  train-02503.jpg -1.000000    False      0.019984
# 2     6b591513796f7731  train-28781.jpg -1.000000    False      0.041020
# 3     d71c3e5ecada3534   test-06509.jpg  0.162512     True      0.062194
# 4     0c2025072e683709  train-25059.jpg -1.000000    False      0.063816
# 5     6cc88caca4ac8cd8  train-01609.jpg -1.000000    False      0.049520
# 6     70848d9e4e5c787c  train-12047.jpg  0.302167     True      0.118758
# 7     5c23f4bc9e76961a  train-00863.jpg -1.000000    False      0.006040
# 8     354dcf313c36382e  train-09578.jpg  0.241548     True      0.077256
# 9     a49c9e1e16bef4b8  train-21940.jpg -1.000000    False      0.035252
# 10    c3c7fe38d8981823  train-15660.jpg  0.206075     True      0.050090
# 11    152567cf8fc78016  train-22493.jpg -1.000000    False      0.023546
# 12    caca524d6d646c6c   test-07892.jpg -1.000000    False      0.038378
# 13    717272f1b436b2b2  train-06865.jpg -1.000000    False      0.020522
# 14    c9698b2b869e96ec  train-30511.jpg  0.311139     True      0.047363
# 15    886261d353521252  train-13907.jpg  0.491170     True      0.047272
# 16    70c6b9b973336434   test-04636.jpg  0.313342     True      0.016910
# 17    e8e4d4e0d0e09a3c  train-21366.jpg -1.000000    False      0.003826
# 18    ddef6b6b73635f7e  train-28860.jpg -1.000000    False      0.026354
# 19    27e6a5b3130b0b8f  train-12866.jpg -1.000000    False      0.186080
# 20    98e0b23065c9d8ea  train-07311.jpg  0.396529     True      0.034603
# 21    c24a49cbc9c90900  train-26196.jpg  0.623421     True      0.089926
# 22    fdc547d2d66ce993  train-25206.jpg  0.401995     True      0.049836
# 23    300666f959c46036  train-12317.jpg  0.462774     True      0.005929
# 24    e17177b5ba9e3626  train-24801.jpg  0.428342     True      0.061470
# 25    f0241065978ac94d  train-23980.jpg  0.458055     True      0.155306
# 26    dfb909341525372d  train-17773.jpg -1.000000    False      0.035528
# 27    60742560644ad393   test-00740.jpg  0.566743     True      0.130545
# 28    181811a53a4e4ccc  train-20057.jpg  0.346170     True      0.071629
# 29    b23868f0d392b4ce  train-10319.jpg  0.402138     True      0.044501
# ...                ...              ...       ...      ...           ...
# 8113  3c13393939a9a4a4  train-02766.jpg -1.000000    False      0.012543
# 8114  ebebd352d2989879  train-13159.jpg  0.275018     True      0.102905
# 8115  dcd8c9d6d6c38e3c  train-26833.jpg -1.000000    False      0.007944
# 8116  83cbd91252c4494b   test-02512.jpg -1.000000    False      0.034173
# 8117  337bcb773fdece1c  train-31851.jpg -1.000000    False      0.045379
# 8118  71484a50b6e8ae9c  train-12024.jpg  0.443576     True      0.029967
# 8119  dccceee7e6eb698c  train-09036.jpg -1.000000    False      0.005743
# 8120  7cbbd2921312b871  train-07187.jpg -1.000000    False      0.048127
# 8121  dfc7776b91b2a6e4  train-11621.jpg -1.000000    False      0.011722
# 8122  e5c1852d10143425  train-30183.jpg -1.000000    False      0.033418
# 8123  c121b797def13332  train-23243.jpg -1.000000    False      0.026097
# 8124  d3d3f0f163ceb071  train-18359.jpg -1.000000    False      0.051537
# 8125  c983d1d3433e9c8e   test-01411.jpg -1.000000    False      0.013232
# 8126  1c30b8b8c4f5a486  train-29903.jpg  0.293033     True      0.045169
# 8127  4777d299b0a493ae  train-24356.jpg  0.314464     True      0.109685
# 8128  c094b75b6a0b7242  train-12560.jpg -1.000000    False      0.076381
# 8129  2b6ed1c8b6496836   test-05949.jpg  0.270693     True      0.038760
# 8130  e272d88c36b2998c   test-07014.jpg  0.437079     True      0.071679
# 8131  2a2b9b3232733213  train-02624.jpg -1.000000    False      0.023541
# 8132  c6c65e25b9d8e6b6  train-12210.jpg -1.000000    False      0.015482
# 8133  c83736a2a29722f1  train-10796.jpg -1.000000    False      0.017887
# 8134  bec5d0dc190f0f44  train-01642.jpg  0.214475     True      0.067096
# 8135  c9b1e4b2aac4a5c4  train-26920.jpg  0.404380     True      0.043363
# 8136  84124c766f35323c  train-15592.jpg  0.292336     True      0.052811
# 8137  898868eb735e56ad  train-01593.jpg -1.000000    False      0.224365
# 8138  bcf8f0f0bc286868  train-01310.jpg -1.000000    False      0.075999
# 8139  01017168580b0b2b  train-23807.jpg -1.000000    False      0.021521
# 8140  f0c9c96ac2d0d0d0  train-04434.jpg -1.000000    False      0.037727
# 8141  e5d30a8ea65512f0  train-20986.jpg -1.000000    False      0.048609
# 8142  b6a4ce762c343696  train-00751.jpg  0.379043     True      0.039904
#
#       pred_violence
# 0          0.230657
# 1          0.251062
# 2          0.200390
# 3          0.225579
# 4          0.256866
# 5          0.267419
# 6          0.330322
# 7          0.296050
# 8          0.238637
# 9          0.294691
# 10         0.306326
# 11         0.250963
# 12         0.263324
# 13         0.265394
# 14         0.215327
# 15         0.220668
# 16         0.262080
# 17         0.195518
# 18         0.262333
# 19         0.260822
# 20         0.213471
# 21         0.300324
# 22         0.275825
# 23         0.241180
# 24         0.190577
# 25         0.242763
# 26         0.311234
# 27         0.317575
# 28         0.231506
# 29         0.293127
# ...             ...
# 8113       0.267744
# 8114       0.288099
# 8115       0.289553
# 8116       0.296208
# 8117       0.248070
# 8118       0.226889
# 8119       0.217038
# 8120       0.257222
# 8121       0.219821
# 8122       0.245432
# 8123       0.258453
# 8124       0.278619
# 8125       0.254486
# 8126       0.304410
# 8127       0.332554
# 8128       0.264075
# 8129       0.311311
# 8130       0.242515
# 8131       0.199339
# 8132       0.229113
# 8133       0.323085
# 8134       0.246124
# 8135       0.248114
# 8136       0.292830
# 8137       0.224290
# 8138       0.253994
# 8139       0.294807
# 8140       0.251901
# 8141       0.247733
# 8142       0.253595
#
# [8143 rows x 6 columns]

# %% [markdown]
# ### Protest

# %%
au.plotROC("protest", preds["protest"], preds["pred_protest"])

# %% [markdown]
# ### Violence

# %%
# remove masked values from test set
non_masked_violence_true = preds[preds["violence"] != - 1]["violence"]
non_masked_violence_preds = preds[preds["violence"] != - 1]["pred_violence"]

fig, ax = plt.subplots()
plt.scatter(non_masked_violence_true, non_masked_violence_preds, label = "violence")
plt.xlim([-.05,1.05])
plt.ylim([-.05,1.05])
plt.xlabel('Annotation', fontsize = 15)
plt.ylabel('Predicton', fontsize = 15)
corr, pval = scipy.stats.pearsonr(non_masked_violence_true, non_masked_violence_preds)
slope, intercept, r_value, p_value, std_err = scipy.stats.linregress(non_masked_violence_true,non_masked_violence_preds)
r_squared = r_value ** 2
plt.title(('{attr} (Correlation = {corr:.3f}, R_squared = {r_2:.3f} )'
            .format(attr = "violence", corr= corr, r_2 = r_squared)), fontsize = 15)
# Out:
# Text(0.5,1,'violence (Correlation = -0.064, R_squared = 0.004 )')
