# %% [markdown]
# ## UCLA model trained on the UCLA dataset without visual attributes evaluation

# %%
import sys
sys.path.append("../../venv/lib/python3.6/site-packages/")
sys.path.append("..")

# %%
import os
import pandas as pd
from lib import analysis_utils as au
import matplotlib.pyplot as plt
import scipy
import numpy as np
# Out:
# /home/jesper/tmp/venv/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ### Load the data

# %%
pred_dir = "models_preds"
# file_name = "UCLA_model_UCLA_dataset_without_visual_attributes_datalen-40720_epochs-100_init_lr-0.01_momentum-0.9_batch_size-32_n_folds-5_n_folds_seed-300.csv"
file_name = 'fully_con_reduced_transform_datalen-40720_epochs-100_init_lr-0.01_momentum-0.9_batch_size-32_n_folds-5_n_folds_seed-300.csv'
preds = pd.read_csv(os.path.join(pred_dir, file_name))
        
print ("loaded ", len(preds), " rows")
# Out:
# loaded  8143  rows

# %%
preds
# Out:
#              imageHASH             name  violence  protest  pred_protest  \
# 0     64adf672a10584f0  train-15308.jpg  0.415880     True  9.937132e-01
# 1     f829656d1b626745  train-02503.jpg -1.000000    False  1.299812e-04
# 2     6b591513796f7731  train-28781.jpg -1.000000    False  8.303839e-08
# 3     d71c3e5ecada3534   test-06509.jpg  0.162512     True  9.707690e-01
# 4     0c2025072e683709  train-25059.jpg -1.000000    False  4.464934e-02
# 5     6cc88caca4ac8cd8  train-01609.jpg -1.000000    False  2.720563e-03
# 6     70848d9e4e5c787c  train-12047.jpg  0.302167     True  9.999946e-01
# 7     5c23f4bc9e76961a  train-00863.jpg -1.000000    False  2.989983e-03
# 8     354dcf313c36382e  train-09578.jpg  0.241548     True  9.662064e-01
# 9     a49c9e1e16bef4b8  train-21940.jpg -1.000000    False  7.017954e-05
# 10    c3c7fe38d8981823  train-15660.jpg  0.206075     True  6.756295e-01
# 11    152567cf8fc78016  train-22493.jpg -1.000000    False  8.564970e-04
# 12    caca524d6d646c6c   test-07892.jpg -1.000000    False  3.838857e-03
# 13    717272f1b436b2b2  train-06865.jpg -1.000000    False  2.513638e-04
# 14    c9698b2b869e96ec  train-30511.jpg  0.311139     True  8.262300e-01
# 15    886261d353521252  train-13907.jpg  0.491170     True  9.496014e-01
# 16    70c6b9b973336434   test-04636.jpg  0.313342     True  9.508543e-01
# 17    e8e4d4e0d0e09a3c  train-21366.jpg -1.000000    False  6.045068e-02
# 18    ddef6b6b73635f7e  train-28860.jpg -1.000000    False  7.659369e-05
# 19    27e6a5b3130b0b8f  train-12866.jpg -1.000000    False  4.486893e-02
# 20    98e0b23065c9d8ea  train-07311.jpg  0.396529     True  8.185288e-01
# 21    c24a49cbc9c90900  train-26196.jpg  0.623421     True  8.459461e-01
# 22    fdc547d2d66ce993  train-25206.jpg  0.401995     True  8.057367e-01
# 23    300666f959c46036  train-12317.jpg  0.462774     True  1.196057e-03
# 24    e17177b5ba9e3626  train-24801.jpg  0.428342     True  9.951839e-01
# 25    f0241065978ac94d  train-23980.jpg  0.458055     True  3.902980e-01
# 26    dfb909341525372d  train-17773.jpg -1.000000    False  4.306130e-03
# 27    60742560644ad393   test-00740.jpg  0.566743     True  7.889447e-01
# 28    181811a53a4e4ccc  train-20057.jpg  0.346170     True  9.762458e-01
# 29    b23868f0d392b4ce  train-10319.jpg  0.402138     True  1.697253e-01
# ...                ...              ...       ...      ...           ...
# 8113  3c13393939a9a4a4  train-02766.jpg -1.000000    False  1.424869e-04
# 8114  ebebd352d2989879  train-13159.jpg  0.275018     True  9.991785e-01
# 8115  dcd8c9d6d6c38e3c  train-26833.jpg -1.000000    False  4.203477e-07
# 8116  83cbd91252c4494b   test-02512.jpg -1.000000    False  2.953987e-04
# 8117  337bcb773fdece1c  train-31851.jpg -1.000000    False  1.420034e-01
# 8118  71484a50b6e8ae9c  train-12024.jpg  0.443576     True  9.896437e-01
# 8119  dccceee7e6eb698c  train-09036.jpg -1.000000    False  1.387893e-08
# 8120  7cbbd2921312b871  train-07187.jpg -1.000000    False  4.264121e-04
# 8121  dfc7776b91b2a6e4  train-11621.jpg -1.000000    False  5.284417e-07
# 8122  e5c1852d10143425  train-30183.jpg -1.000000    False  1.696928e-01
# 8123  c121b797def13332  train-23243.jpg -1.000000    False  1.063311e-01
# 8124  d3d3f0f163ceb071  train-18359.jpg -1.000000    False  2.715570e-03
# 8125  c983d1d3433e9c8e   test-01411.jpg -1.000000    False  9.560755e-05
# 8126  1c30b8b8c4f5a486  train-29903.jpg  0.293033     True  9.985480e-01
# 8127  4777d299b0a493ae  train-24356.jpg  0.314464     True  9.816654e-01
# 8128  c094b75b6a0b7242  train-12560.jpg -1.000000    False  3.804343e-02
# 8129  2b6ed1c8b6496836   test-05949.jpg  0.270693     True  9.999940e-01
# 8130  e272d88c36b2998c   test-07014.jpg  0.437079     True  9.390649e-01
# 8131  2a2b9b3232733213  train-02624.jpg -1.000000    False  3.291686e-01
# 8132  c6c65e25b9d8e6b6  train-12210.jpg -1.000000    False  6.324114e-01
# 8133  c83736a2a29722f1  train-10796.jpg -1.000000    False  1.943406e-06
# 8134  bec5d0dc190f0f44  train-01642.jpg  0.214475     True  6.853832e-01
# 8135  c9b1e4b2aac4a5c4  train-26920.jpg  0.404380     True  1.113952e-01
# 8136  84124c766f35323c  train-15592.jpg  0.292336     True  9.976405e-01
# 8137  898868eb735e56ad  train-01593.jpg -1.000000    False  1.714037e-02
# 8138  bcf8f0f0bc286868  train-01310.jpg -1.000000    False  3.456893e-02
# 8139  01017168580b0b2b  train-23807.jpg -1.000000    False  5.244614e-01
# 8140  f0c9c96ac2d0d0d0  train-04434.jpg -1.000000    False  8.980135e-01
# 8141  e5d30a8ea65512f0  train-20986.jpg -1.000000    False  9.512983e-02
# 8142  b6a4ce762c343696  train-00751.jpg  0.379043     True  6.703954e-01
#
#       pred_violence
# 0          0.403324
# 1          0.140942
# 2          0.067362
# 3          0.178976
# 4          0.308561
# 5          0.146608
# 6          0.274059
# 7          0.198909
# 8          0.218164
# 9          0.131750
# 10         0.165176
# 11         0.169883
# 12         0.212036
# 13         0.207842
# 14         0.261751
# 15         0.382047
# 16         0.288540
# 17         0.340960
# 18         0.209967
# 19         0.165474
# 20         0.333342
# 21         0.473683
# 22         0.409130
# 23         0.232647
# 24         0.410581
# 25         0.414783
# 26         0.187889
# 27         0.430365
# 28         0.278391
# 29         0.432172
# ...             ...
# 8113       0.286412
# 8114       0.227380
# 8115       0.101670
# 8116       0.166411
# 8117       0.237771
# 8118       0.376347
# 8119       0.061380
# 8120       0.124572
# 8121       0.074489
# 8122       0.315900
# 8123       0.173237
# 8124       0.215428
# 8125       0.196442
# 8126       0.344651
# 8127       0.222130
# 8128       0.176824
# 8129       0.231055
# 8130       0.447485
# 8131       0.216498
# 8132       0.380393
# 8133       0.097089
# 8134       0.298519
# 8135       0.434204
# 8136       0.348671
# 8137       0.344877
# 8138       0.485879
# 8139       0.498853
# 8140       0.432707
# 8141       0.273123
# 8142       0.313653
#
# [8143 rows x 6 columns]

# %% [markdown]
# ### Protest

# %%
au.plotROC("protest", preds["protest"], preds["pred_protest"])

# %% [markdown]
# ### Violence

# %%
# remove masked values from test set
non_masked_violence_true = preds[preds["violence"] != - 1]["violence"]
non_masked_violence_preds = preds[preds["violence"] != - 1]["pred_violence"]

fig, ax = plt.subplots()
plt.scatter(non_masked_violence_true, non_masked_violence_preds, label = "violence")
plt.xlim([-.05,1.05])
plt.ylim([-.05,1.05])
plt.xlabel('Annotation', fontsize = 15)
plt.ylabel('Predicton', fontsize = 15)
corr, pval = scipy.stats.pearsonr(non_masked_violence_true, non_masked_violence_preds)
slope, intercept, r_value, p_value, std_err = scipy.stats.linregress(non_masked_violence_true,non_masked_violence_preds)
r_squared = r_value ** 2
plt.title(('{attr} (Correlation = {corr:.3f}, R_squared = {r_2:.3f} )'
            .format(attr = "violence", corr= corr, r_2 = r_squared)), fontsize = 15)
# Out:
# Text(0.5,1,'violence (Correlation = 0.889, R_squared = 0.789 )')
