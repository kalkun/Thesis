# %% [markdown]
# ## UCLA model trained on the UCLA dataset without visual attributes evaluation

# %%
import sys
sys.path.append("../../venv/lib/python3.6/site-packages/")
sys.path.append("..")

# %%
import os
import pandas as pd
from lib import analysis_utils as au
import matplotlib.pyplot as plt
import scipy
import numpy as np
# Out:
# /home/jesper/tmp/venv/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ### Load the data

# %%
pred_dir = "models_preds"
# file_name = "UCLA_model_UCLA_dataset_without_visual_attributes_datalen-40720_epochs-100_init_lr-0.01_momentum-0.9_batch_size-32_n_folds-5_n_folds_seed-300.csv"
file_name = 'fully_con_reduced_transform_datalen-40720_weight-1:100_epochs-100_init_lr-0.01_momentum-0.9_batch_size-32_n_folds-5_n_folds_seed-300.csv'
preds = pd.read_csv(os.path.join(pred_dir, file_name))
        
print ("loaded ", len(preds), " rows")
# Out:
# loaded  8143  rows

# %%
preds
# Out:
#              imageHASH             name  violence  protest  pred_protest  \
# 0     64adf672a10584f0  train-15308.jpg  0.415880     True      0.901703
# 1     f829656d1b626745  train-02503.jpg -1.000000    False      0.003618
# 2     6b591513796f7731  train-28781.jpg -1.000000    False      0.000019
# 3     d71c3e5ecada3534   test-06509.jpg  0.162512     True      0.949871
# 4     0c2025072e683709  train-25059.jpg -1.000000    False      0.004957
# 5     6cc88caca4ac8cd8  train-01609.jpg -1.000000    False      0.000171
# 6     70848d9e4e5c787c  train-12047.jpg  0.302167     True      0.999554
# 7     5c23f4bc9e76961a  train-00863.jpg -1.000000    False      0.013198
# 8     354dcf313c36382e  train-09578.jpg  0.241548     True      0.745837
# 9     a49c9e1e16bef4b8  train-21940.jpg -1.000000    False      0.000207
# 10    c3c7fe38d8981823  train-15660.jpg  0.206075     True      0.462804
# 11    152567cf8fc78016  train-22493.jpg -1.000000    False      0.000079
# 12    caca524d6d646c6c   test-07892.jpg -1.000000    False      0.006970
# 13    717272f1b436b2b2  train-06865.jpg -1.000000    False      0.000003
# 14    c9698b2b869e96ec  train-30511.jpg  0.311139     True      0.840336
# 15    886261d353521252  train-13907.jpg  0.491170     True      0.682549
# 16    70c6b9b973336434   test-04636.jpg  0.313342     True      0.957406
# 17    e8e4d4e0d0e09a3c  train-21366.jpg -1.000000    False      0.096889
# 18    ddef6b6b73635f7e  train-28860.jpg -1.000000    False      0.000111
# 19    27e6a5b3130b0b8f  train-12866.jpg -1.000000    False      0.038507
# 20    98e0b23065c9d8ea  train-07311.jpg  0.396529     True      0.611180
# 21    c24a49cbc9c90900  train-26196.jpg  0.623421     True      0.852169
# 22    fdc547d2d66ce993  train-25206.jpg  0.401995     True      0.501342
# 23    300666f959c46036  train-12317.jpg  0.462774     True      0.000705
# 24    e17177b5ba9e3626  train-24801.jpg  0.428342     True      0.885379
# 25    f0241065978ac94d  train-23980.jpg  0.458055     True      0.204040
# 26    dfb909341525372d  train-17773.jpg -1.000000    False      0.002395
# 27    60742560644ad393   test-00740.jpg  0.566743     True      0.380213
# 28    181811a53a4e4ccc  train-20057.jpg  0.346170     True      0.946562
# 29    b23868f0d392b4ce  train-10319.jpg  0.402138     True      0.528247
# ...                ...              ...       ...      ...           ...
# 8113  3c13393939a9a4a4  train-02766.jpg -1.000000    False      0.000551
# 8114  ebebd352d2989879  train-13159.jpg  0.275018     True      0.980982
# 8115  dcd8c9d6d6c38e3c  train-26833.jpg -1.000000    False      0.000014
# 8116  83cbd91252c4494b   test-02512.jpg -1.000000    False      0.003068
# 8117  337bcb773fdece1c  train-31851.jpg -1.000000    False      0.012454
# 8118  71484a50b6e8ae9c  train-12024.jpg  0.443576     True      0.907985
# 8119  dccceee7e6eb698c  train-09036.jpg -1.000000    False      0.000358
# 8120  7cbbd2921312b871  train-07187.jpg -1.000000    False      0.000056
# 8121  dfc7776b91b2a6e4  train-11621.jpg -1.000000    False      0.000652
# 8122  e5c1852d10143425  train-30183.jpg -1.000000    False      0.176870
# 8123  c121b797def13332  train-23243.jpg -1.000000    False      0.003161
# 8124  d3d3f0f163ceb071  train-18359.jpg -1.000000    False      0.000013
# 8125  c983d1d3433e9c8e   test-01411.jpg -1.000000    False      0.000203
# 8126  1c30b8b8c4f5a486  train-29903.jpg  0.293033     True      0.950925
# 8127  4777d299b0a493ae  train-24356.jpg  0.314464     True      0.754233
# 8128  c094b75b6a0b7242  train-12560.jpg -1.000000    False      0.001946
# 8129  2b6ed1c8b6496836   test-05949.jpg  0.270693     True      0.998760
# 8130  e272d88c36b2998c   test-07014.jpg  0.437079     True      0.883918
# 8131  2a2b9b3232733213  train-02624.jpg -1.000000    False      0.027717
# 8132  c6c65e25b9d8e6b6  train-12210.jpg -1.000000    False      0.107892
# 8133  c83736a2a29722f1  train-10796.jpg -1.000000    False      0.000037
# 8134  bec5d0dc190f0f44  train-01642.jpg  0.214475     True      0.705361
# 8135  c9b1e4b2aac4a5c4  train-26920.jpg  0.404380     True      0.052846
# 8136  84124c766f35323c  train-15592.jpg  0.292336     True      0.931216
# 8137  898868eb735e56ad  train-01593.jpg -1.000000    False      0.009182
# 8138  bcf8f0f0bc286868  train-01310.jpg -1.000000    False      0.332861
# 8139  01017168580b0b2b  train-23807.jpg -1.000000    False      0.552084
# 8140  f0c9c96ac2d0d0d0  train-04434.jpg -1.000000    False      0.942396
# 8141  e5d30a8ea65512f0  train-20986.jpg -1.000000    False      0.191116
# 8142  b6a4ce762c343696  train-00751.jpg  0.379043     True      0.249878
#
#       pred_violence
# 0      5.694952e-11
# 1      6.897799e-29
# 2      0.000000e+00
# 3      7.104575e-23
# 4      1.468995e-16
# 5      5.492451e-34
# 6      2.752101e-20
# 7      3.158226e-20
# 8      7.868050e-20
# 9      1.610716e-26
# 10     3.324807e-16
# 11     1.973351e-23
# 12     9.177662e-18
# 13     0.000000e+00
# 14     5.107634e-17
# 15     2.089284e-13
# 16     9.496353e-15
# 17     3.670230e-12
# 18     1.829854e-38
# 19     1.204224e-18
# 20     1.304515e-10
# 21     2.245982e-12
# 22     1.513379e-11
# 23     3.806434e-30
# 24     1.153220e-13
# 25     5.726703e-15
# 26     9.496542e-21
# 27     1.964518e-16
# 28     4.193460e-13
# 29     2.199438e-12
# ...             ...
# 8113   0.000000e+00
# 8114   6.204109e-20
# 8115   0.000000e+00
# 8116   7.561044e-32
# 8117   7.655523e-22
# 8118   1.360664e-13
# 8119   0.000000e+00
# 8120   0.000000e+00
# 8121   2.269549e-35
# 8122   2.515090e-14
# 8123   4.821941e-24
# 8124   0.000000e+00
# 8125   0.000000e+00
# 8126   3.056105e-16
# 8127   1.032954e-20
# 8128   8.396041e-18
# 8129   1.632109e-20
# 8130   7.279500e-14
# 8131   1.405498e-18
# 8132   1.512445e-10
# 8133   9.764815e-30
# 8134   6.430132e-17
# 8135   5.169015e-13
# 8136   1.314927e-15
# 8137   3.333111e-17
# 8138   9.463271e-10
# 8139   3.509341e-11
# 8140   2.368896e-13
# 8141   8.505791e-15
# 8142   4.619347e-17
#
# [8143 rows x 6 columns]

# %% [markdown]
# ### Protest

# %%
au.plotROC("protest", preds["protest"], preds["pred_protest"])

# %% [markdown]
# ### Violence

# %%
# remove masked values from test set
non_masked_violence_true = preds[preds["violence"] != - 1]["violence"]
non_masked_violence_preds = preds[preds["violence"] != - 1]["pred_violence"]

fig, ax = plt.subplots()
plt.scatter(non_masked_violence_true, non_masked_violence_preds, label = "violence")
plt.xlim([-.05,1.05])
plt.ylim([-.05,1.05])
plt.xlabel('Annotation', fontsize = 15)
plt.ylabel('Predicton', fontsize = 15)
corr, pval = scipy.stats.pearsonr(non_masked_violence_true, non_masked_violence_preds)
slope, intercept, r_value, p_value, std_err = scipy.stats.linregress(non_masked_violence_true,non_masked_violence_preds)
r_squared = r_value ** 2
plt.title(('{attr} (Correlation = {corr:.3f}, R_squared = {r_2:.3f} )'
            .format(attr = "violence", corr= corr, r_2 = r_squared)), fontsize = 15)
# Out:
# Text(0.5,1,'violence (Correlation = 0.037, R_squared = 0.001 )')
