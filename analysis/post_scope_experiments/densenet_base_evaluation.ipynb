# %% [markdown]
# ## Dense net evaluation

# %%
import sys
sys.path.append("../../venv/lib/python3.6/site-packages/")
sys.path.append("..")

# %%
import os
import pandas as pd
from lib import analysis_utils as au
import matplotlib.pyplot as plt
import scipy
import numpy as np
# Out:
# /home/lucas/Documents/ITU/Thesis_2018/venv/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ### Load the data

# %%
pred_dir = "models_preds"
# file_name = "UCLA_model_UCLA_dataset_without_visual_attributes_datalen-40720_epochs-100_init_lr-0.01_momentum-0.9_batch_size-32_n_folds-5_n_folds_seed-300.csv"
file_name = 'densenet_base_datalen-40720_epochs-100_init_lr-0.01_momentum-0.9_batch_size-32_n_folds-5_n_folds_seed-300.csv'
preds = pd.read_csv(os.path.join(pred_dir, file_name))
        
print ("loaded ", len(preds), " rows")
# Out:
# loaded  8143  rows

# %%
preds
# Out:
#              imageHASH             name  violence  protest  pred_protest  \
# 0     64adf672a10584f0  train-15308.jpg  0.415880     True           0.0
# 1     f829656d1b626745  train-02503.jpg -1.000000    False           0.0
# 2     6b591513796f7731  train-28781.jpg -1.000000    False           0.0
# 3     d71c3e5ecada3534   test-06509.jpg  0.162512     True           0.0
# 4     0c2025072e683709  train-25059.jpg -1.000000    False           0.0
# 5     6cc88caca4ac8cd8  train-01609.jpg -1.000000    False           0.0
# 6     70848d9e4e5c787c  train-12047.jpg  0.302167     True           0.0
# 7     5c23f4bc9e76961a  train-00863.jpg -1.000000    False           0.0
# 8     354dcf313c36382e  train-09578.jpg  0.241548     True           0.0
# 9     a49c9e1e16bef4b8  train-21940.jpg -1.000000    False           0.0
# 10    c3c7fe38d8981823  train-15660.jpg  0.206075     True           0.0
# 11    152567cf8fc78016  train-22493.jpg -1.000000    False           0.0
# 12    caca524d6d646c6c   test-07892.jpg -1.000000    False           0.0
# 13    717272f1b436b2b2  train-06865.jpg -1.000000    False           0.0
# 14    c9698b2b869e96ec  train-30511.jpg  0.311139     True           0.0
# 15    886261d353521252  train-13907.jpg  0.491170     True           0.0
# 16    70c6b9b973336434   test-04636.jpg  0.313342     True           0.0
# 17    e8e4d4e0d0e09a3c  train-21366.jpg -1.000000    False           0.0
# 18    ddef6b6b73635f7e  train-28860.jpg -1.000000    False           0.0
# 19    27e6a5b3130b0b8f  train-12866.jpg -1.000000    False           0.0
# 20    98e0b23065c9d8ea  train-07311.jpg  0.396529     True           0.0
# 21    c24a49cbc9c90900  train-26196.jpg  0.623421     True           0.0
# 22    fdc547d2d66ce993  train-25206.jpg  0.401995     True           0.0
# 23    300666f959c46036  train-12317.jpg  0.462774     True           0.0
# 24    e17177b5ba9e3626  train-24801.jpg  0.428342     True           0.0
# 25    f0241065978ac94d  train-23980.jpg  0.458055     True           0.0
# 26    dfb909341525372d  train-17773.jpg -1.000000    False           0.0
# 27    60742560644ad393   test-00740.jpg  0.566743     True           0.0
# 28    181811a53a4e4ccc  train-20057.jpg  0.346170     True           0.0
# 29    b23868f0d392b4ce  train-10319.jpg  0.402138     True           0.0
# ...                ...              ...       ...      ...           ...
# 8113  3c13393939a9a4a4  train-02766.jpg -1.000000    False           0.0
# 8114  ebebd352d2989879  train-13159.jpg  0.275018     True           0.0
# 8115  dcd8c9d6d6c38e3c  train-26833.jpg -1.000000    False           0.0
# 8116  83cbd91252c4494b   test-02512.jpg -1.000000    False           0.0
# 8117  337bcb773fdece1c  train-31851.jpg -1.000000    False           0.0
# 8118  71484a50b6e8ae9c  train-12024.jpg  0.443576     True           0.0
# 8119  dccceee7e6eb698c  train-09036.jpg -1.000000    False           0.0
# 8120  7cbbd2921312b871  train-07187.jpg -1.000000    False           0.0
# 8121  dfc7776b91b2a6e4  train-11621.jpg -1.000000    False           0.0
# 8122  e5c1852d10143425  train-30183.jpg -1.000000    False           0.0
# 8123  c121b797def13332  train-23243.jpg -1.000000    False           0.0
# 8124  d3d3f0f163ceb071  train-18359.jpg -1.000000    False           0.0
# 8125  c983d1d3433e9c8e   test-01411.jpg -1.000000    False           0.0
# 8126  1c30b8b8c4f5a486  train-29903.jpg  0.293033     True           0.0
# 8127  4777d299b0a493ae  train-24356.jpg  0.314464     True           0.0
# 8128  c094b75b6a0b7242  train-12560.jpg -1.000000    False           0.0
# 8129  2b6ed1c8b6496836   test-05949.jpg  0.270693     True           0.0
# 8130  e272d88c36b2998c   test-07014.jpg  0.437079     True           0.0
# 8131  2a2b9b3232733213  train-02624.jpg -1.000000    False           0.0
# 8132  c6c65e25b9d8e6b6  train-12210.jpg -1.000000    False           0.0
# 8133  c83736a2a29722f1  train-10796.jpg -1.000000    False           0.0
# 8134  bec5d0dc190f0f44  train-01642.jpg  0.214475     True           0.0
# 8135  c9b1e4b2aac4a5c4  train-26920.jpg  0.404380     True           0.0
# 8136  84124c766f35323c  train-15592.jpg  0.292336     True           0.0
# 8137  898868eb735e56ad  train-01593.jpg -1.000000    False           0.0
# 8138  bcf8f0f0bc286868  train-01310.jpg -1.000000    False           0.0
# 8139  01017168580b0b2b  train-23807.jpg -1.000000    False           0.0
# 8140  f0c9c96ac2d0d0d0  train-04434.jpg -1.000000    False           0.0
# 8141  e5d30a8ea65512f0  train-20986.jpg -1.000000    False           0.0
# 8142  b6a4ce762c343696  train-00751.jpg  0.379043     True           0.0
#
#       pred_violence
# 0      0.000000e+00
# 1      1.722285e-29
# 2      3.353293e-28
# 3      1.233569e-29
# 4      1.123483e-27
# 5      2.522624e-32
# 6      2.962840e-28
# 7      1.875738e-29
# 8      6.053247e-29
# 9      8.980111e-28
# 10     5.832690e-28
# 11     1.110445e-27
# 12     3.641896e-28
# 13     0.000000e+00
# 14     0.000000e+00
# 15     0.000000e+00
# 16     1.785703e-35
# 17     0.000000e+00
# 18     9.973800e-29
# 19     2.561640e-29
# 20     2.306916e-28
# 21     1.765272e-32
# 22     5.585838e-29
# 23     1.013001e-28
# 24     0.000000e+00
# 25     1.780633e-38
# 26     4.791891e-30
# 27     1.457342e-29
# 28     2.936692e-34
# 29     4.318775e-28
# ...             ...
# 8113   3.809443e-29
# 8114   1.735131e-29
# 8115   0.000000e+00
# 8116   1.202235e-28
# 8117   8.739444e-30
# 8118   9.265876e-28
# 8119   0.000000e+00
# 8120   0.000000e+00
# 8121   4.967367e-30
# 8122   1.292460e-28
# 8123   1.603708e-27
# 8124   5.096609e-28
# 8125   9.102334e-29
# 8126   1.036621e-28
# 8127   3.188986e-36
# 8128   2.235412e-28
# 8129   5.486605e-28
# 8130   6.969896e-31
# 8131   3.390050e-29
# 8132   3.254599e-30
# 8133   1.966569e-34
# 8134   6.179190e-28
# 8135   0.000000e+00
# 8136   4.378391e-29
# 8137   9.788324e-35
# 8138   0.000000e+00
# 8139   1.062127e-27
# 8140   1.992346e-28
# 8141   1.520006e-27
# 8142   2.676559e-29
#
# [8143 rows x 6 columns]

# %% [markdown]
# ### Protest

# %%
au.plotROC("protest", preds["protest"], preds["pred_protest"])

# %% [markdown]
# ### Violence

# %%
# remove masked values from test set
non_masked_violence_true = preds[preds["violence"] != - 1]["violence"]
non_masked_violence_preds = preds[preds["violence"] != - 1]["pred_violence"]

fig, ax = plt.subplots()
plt.scatter(non_masked_violence_true, non_masked_violence_preds, label = "violence")
plt.xlim([-.05,1.05])
plt.ylim([-.05,1.05])
plt.xlabel('Annotation', fontsize = 15)
plt.ylabel('Predicton', fontsize = 15)
corr, pval = scipy.stats.pearsonr(non_masked_violence_true, non_masked_violence_preds)
slope, intercept, r_value, p_value, std_err = scipy.stats.linregress(non_masked_violence_true,non_masked_violence_preds)
r_squared = r_value ** 2
plt.title(('{attr} (Correlation = {corr:.3f}, R_squared = {r_2:.3f} )'
            .format(attr = "violence", corr= corr, r_2 = r_squared)), fontsize = 15)
# Out:
# Text(0.5,1,'violence (Correlation = -0.052, R_squared = 0.003 )')
