# %% [markdown]
# # Fully connected layer, 3 multitasks, reduced transformation
# This notebook seeks to combine the finding that having two fully connected layers to each of three multitask outcomes as well as reducing the randomresizedcrop in the input transformation. This is of course in the hope, that since they each performed well, then perhaps they do even better together.
#
# This notebook uses all three label types; visual attributes, violence and protest labels

# %%
import sys
sys.path.append("../../venv/lib/python3.6/site-packages/")
sys.path.append("../")

# %%
from protestDB import cursor
import time
from protestDB import models
from lib import analysis_utils as au
import pandas as pd
import os
from matplotlib import pyplot as plt
from PIL import Image
import numpy as np
import scipy
from keras import backend as Kbackend
from keras import callbacks as Kcallbacks
from keras import optimizers as Koptimizers
from keras import losses as Klosses
from keras import models as Kmodels
from keras import backend as Kbackend
from keras import applications as Kapplications
from keras import layers as Klayers
import h5py
import itertools
from lib import transforms
# Out:
# /home/jesper/tmp/venv/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ### Loading up the data

# %%
pc = cursor.ProtestCursor()
imgs = pc.getLabelledImagesAndNonProtest(source="UCLA", label_source="UCLA original")
len(imgs)
# Out:
# 40720

# %% [markdown]
# ### Preprocessing

# %%
cols = ["name", "label", "protest"]
tag_cols = ["sign", "photo", "fire", "police", "children", "group_20", "group_100", "flag", "night", "shouting"]
imgs = imgs[cols + tag_cols]
indx_non_violence = imgs['label'].isnull()
imgs = imgs.rename(columns={"label": "violence"})
imgs
# Out:
#                              name  violence  protest   sign  photo   fire  \
# imageHASH
# 030d92ca8d1f4b6b   test-00000.jpg  0.209786     True   True  False  False
# c7c6cecccc6ae6a4   test-00001.jpg       NaN    False  False  False  False
# 94c4c6443cbc9c14   test-00002.jpg  0.122890     True   True  False  False
# f2f068703a38e869   test-00003.jpg       NaN    False  False  False  False
# 83a2860706c6e5e4   test-00004.jpg       NaN    False  False  False  False
# 1890151c5859c8f8   test-00005.jpg       NaN    False  False  False  False
# 7f5b59cbdc543c2c   test-00006.jpg       NaN    False  False  False  False
# 6264e0c0a0c0a0d0   test-00007.jpg       NaN    False  False  False  False
# eee6e6e6c68f95b5   test-00008.jpg       NaN    False  False  False  False
# 2f2d252159d9898c   test-00009.jpg       NaN    False  False  False  False
# 0b2cf29e92aa294f   test-00010.jpg  0.186237     True   True  False  False
# 894169e3e1cb4b4b   test-00011.jpg       NaN    False  False  False  False
# 97b2d8f4ece0b4c4   test-00012.jpg       NaN    False  False  False  False
# 160335f46456562e   test-00013.jpg  0.108334     True   True  False  False
# bedbdfdede7efe9e   test-00014.jpg       NaN    False  False  False  False
# 27658736f5993533   test-00015.jpg       NaN    False  False  False  False
# 744b59757515a563   test-00016.jpg       NaN    False  False  False  False
# c6c6ae7929a8d463   test-00017.jpg       NaN    False  False  False  False
# 7955636367796961   test-00018.jpg       NaN    False  False  False  False
# ec6cc6d6a6c7e5c4   test-00019.jpg       NaN    False  False  False  False
# 6a22e2626c464360   test-00020.jpg  0.123604     True   True  False  False
# 43e0144c4c4c4c33   test-00021.jpg       NaN    False  False  False  False
# ca61a59cb687c8cd   test-00022.jpg       NaN    False  False  False  False
# 6e7e7cdc5d7968b8   test-00023.jpg       NaN    False  False  False  False
# b2ed071303870131   test-00024.jpg       NaN    False  False  False  False
# d87930353555f061   test-00025.jpg       NaN    False  False  False  False
# 68d0981856141cf7   test-00026.jpg       NaN    False  False  False  False
# c5466a57ec6e660f   test-00027.jpg       NaN    False  False  False  False
# 7864656be2a2260b   test-00028.jpg  0.168648     True   True  False  False
# a494c469ac8e8ec4   test-00029.jpg  0.190641     True   True  False  False
# ...                           ...       ...      ...    ...    ...    ...
# 88e8ba7a89b87400  train-32234.jpg       NaN    False  False  False  False
# 2125a8ac9cb13b3a  train-32236.jpg       NaN    False  False  False  False
# 2e0f77d76b737373  train-32241.jpg       NaN    False  False  False  False
# 1e2e2a5d999bd353  train-32244.jpg       NaN    False  False  False  False
# ccff26d199193dea  train-32251.jpg       NaN    False  False  False  False
# a660746834a361d9  train-32254.jpg       NaN    False  False  False  False
# 80d479692c050ccc  train-32259.jpg       NaN    False  False  False  False
# 18d94b35312d4520  train-32296.jpg       NaN    False  False  False  False
# 4726605a56decde9  train-32303.jpg       NaN    False  False  False  False
# 3333b1946b2f475b  train-32309.jpg       NaN    False  False  False  False
# 7236cc6c599998e5  train-32317.jpg       NaN    False  False  False  False
# 7373391db7723998  train-32338.jpg       NaN    False  False  False  False
# d773b9199094ba30  train-32339.jpg       NaN    False  False  False  False
# cba3ad29436465a6  train-32387.jpg  0.102998     True   True  False  False
# f5b6636171929f16  train-32419.jpg       NaN    False  False  False  False
# 9c99c9d8163bb125  train-32433.jpg       NaN    False  False  False  False
# 484925ab65cdc9eb  train-32440.jpg       NaN    False  False  False  False
# 3969cbc7c6da1a0b  train-32457.jpg       NaN    False  False  False  False
# 2c21d1119f4b4656  train-32473.jpg  0.217607     True   True  False  False
# c0c8b092b89b8487  train-32486.jpg       NaN    False  False  False  False
# 484c26b2d0c8c8a0  train-32495.jpg       NaN    False  False  False  False
# 6ec26078656798c4  train-32497.jpg       NaN    False  False  False  False
# 0057b7a96b4c1d00  train-32524.jpg       NaN    False  False  False  False
# 1431d393b1b9b987  train-32565.jpg       NaN    False  False  False  False
# 163617393d1d3e1c  train-32568.jpg       NaN    False  False  False  False
# 87cb5565e5b331b9  train-32569.jpg       NaN    False  False  False  False
# 0901021290b5a5ad  train-32571.jpg  0.146799     True   True  False  False
# fafa6ac2b3f20a84  train-32579.jpg       NaN    False  False  False  False
# 5ddcdc1e3f1a1db3  train-32589.jpg  0.126320     True   True  False  False
# 2da46665c1c1e52a  train-32602.jpg       NaN    False  False  False  False
#
#                   police  children  group_20  group_100   flag  night  \
# imageHASH
# 030d92ca8d1f4b6b   False     False      True       True  False   True
# c7c6cecccc6ae6a4   False     False     False      False  False  False
# 94c4c6443cbc9c14   False     False     False      False  False  False
# f2f068703a38e869   False     False     False      False  False  False
# 83a2860706c6e5e4   False     False     False      False  False  False
# 1890151c5859c8f8   False     False     False      False  False  False
# 7f5b59cbdc543c2c   False     False     False      False  False  False
# 6264e0c0a0c0a0d0   False     False     False      False  False  False
# eee6e6e6c68f95b5   False     False     False      False  False  False
# 2f2d252159d9898c   False     False     False      False  False  False
# 0b2cf29e92aa294f   False     False      True       True  False  False
# 894169e3e1cb4b4b   False     False     False      False  False  False
# 43e0144c4c4c4c33     False
# ca61a59cb687c8cd     False
# 6e7e7cdc5d7968b8     False
# b2ed071303870131     False
# d87930353555f061     False
# 68d0981856141cf7     False
# c5466a57ec6e660f     False
# 7864656be2a2260b     False
# a494c469ac8e8ec4     False
# ...                    ...
# 88e8ba7a89b87400     False
# 2125a8ac9cb13b3a     False
# 2e0f77d76b737373     False
# 1e2e2a5d999bd353     False
# ccff26d199193dea     False
# a660746834a361d9     False
# 80d479692c050ccc     False
# 18d94b35312d4520     False
# 4726605a56decde9     False
# 3333b1946b2f475b     False
# 7236cc6c599998e5     False
# 7373391db7723998     False
# d773b9199094ba30     False
# cba3ad29436465a6     False
# f5b6636171929f16     False
# 9c99c9d8163bb125     False
# 484925ab65cdc9eb     False
# 3969cbc7c6da1a0b     False
# 2c21d1119f4b4656     False
# c0c8b092b89b8487     False
# 484c26b2d0c8c8a0     False
# 6ec26078656798c4     False
# 0057b7a96b4c1d00     False
# 1431d393b1b9b987     False
# 163617393d1d3e1c     False
# 87cb5565e5b331b9     False
# 0901021290b5a5ad     False
# fafa6ac2b3f20a84     False
# 5ddcdc1e3f1a1db3     False
# 2da46665c1c1e52a     False
#
# [40720 rows x 13 columns]

# %%
# Apply a cut point and normalize violence scores
cutpoint = 0.43

#clips
imgs = au.clipDFColumn(imgs, 'violence', cutpoint)

# normalize
imgs = au.minMax(imgs, 'violence')

# mask values that did not had violence labels
imgs.loc[indx_non_violence, "violence"] = -1

df = imgs
df
# Out:
#                              name  violence  protest   sign  photo   fire  \
# imageHASH
# 030d92ca8d1f4b6b   test-00000.jpg  0.487873     True   True  False  False
# c7c6cecccc6ae6a4   test-00001.jpg -1.000000    False  False  False  False
# 94c4c6443cbc9c14   test-00002.jpg  0.285790     True   True  False  False
# f2f068703a38e869   test-00003.jpg -1.000000    False  False  False  False
# 83a2860706c6e5e4   test-00004.jpg -1.000000    False  False  False  False
# 1890151c5859c8f8   test-00005.jpg -1.000000    False  False  False  False
# 7f5b59cbdc543c2c   test-00006.jpg -1.000000    False  False  False  False
# 6264e0c0a0c0a0d0   test-00007.jpg -1.000000    False  False  False  False
# eee6e6e6c68f95b5   test-00008.jpg -1.000000    False  False  False  False
# 2f2d252159d9898c   test-00009.jpg -1.000000    False  False  False  False
# 0b2cf29e92aa294f   test-00010.jpg  0.433110     True   True  False  False
# 894169e3e1cb4b4b   test-00011.jpg -1.000000    False  False  False  False
# 97b2d8f4ece0b4c4   test-00012.jpg -1.000000    False  False  False  False
# 160335f46456562e   test-00013.jpg  0.251941     True   True  False  False
# bedbdfdede7efe9e   test-00014.jpg -1.000000    False  False  False  False
# 27658736f5993533   test-00015.jpg -1.000000    False  False  False  False
# 744b59757515a563   test-00016.jpg -1.000000    False  False  False  False
# c6c6ae7929a8d463   test-00017.jpg -1.000000    False  False  False  False
# 7955636367796961   test-00018.jpg -1.000000    False  False  False  False
# ec6cc6d6a6c7e5c4   test-00019.jpg -1.000000    False  False  False  False
# 6a22e2626c464360   test-00020.jpg  0.287450     True   True  False  False
# 43e0144c4c4c4c33   test-00021.jpg -1.000000    False  False  False  False
# ca61a59cb687c8cd   test-00022.jpg -1.000000    False  False  False  False
# 6e7e7cdc5d7968b8   test-00023.jpg -1.000000    False  False  False  False
# b2ed071303870131   test-00024.jpg -1.000000    False  False  False  False
# d87930353555f061   test-00025.jpg -1.000000    False  False  False  False
# 68d0981856141cf7   test-00026.jpg -1.000000    False  False  False  False
# c5466a57ec6e660f   test-00027.jpg -1.000000    False  False  False  False
# 7864656be2a2260b   test-00028.jpg  0.392205     True   True  False  False
# a494c469ac8e8ec4   test-00029.jpg  0.443350     True   True  False  False
# ...                           ...       ...      ...    ...    ...    ...
# 88e8ba7a89b87400  train-32234.jpg -1.000000    False  False  False  False
# 2125a8ac9cb13b3a  train-32236.jpg -1.000000    False  False  False  False
# 2e0f77d76b737373  train-32241.jpg -1.000000    False  False  False  False
# 1e2e2a5d999bd353  train-32244.jpg -1.000000    False  False  False  False
# ccff26d199193dea  train-32251.jpg -1.000000    False  False  False  False
# a660746834a361d9  train-32254.jpg -1.000000    False  False  False  False
# 80d479692c050ccc  train-32259.jpg -1.000000    False  False  False  False
# 18d94b35312d4520  train-32296.jpg -1.000000    False  False  False  False
# 4726605a56decde9  train-32303.jpg -1.000000    False  False  False  False
# 3333b1946b2f475b  train-32309.jpg -1.000000    False  False  False  False
# 7236cc6c599998e5  train-32317.jpg -1.000000    False  False  False  False
# 7373391db7723998  train-32338.jpg -1.000000    False  False  False  False
# d773b9199094ba30  train-32339.jpg -1.000000    False  False  False  False
# cba3ad29436465a6  train-32387.jpg  0.239531     True   True  False  False
# f5b6636171929f16  train-32419.jpg -1.000000    False  False  False  False
# 9c99c9d8163bb125  train-32433.jpg -1.000000    False  False  False  False
# 484925ab65cdc9eb  train-32440.jpg -1.000000    False  False  False  False
# 3969cbc7c6da1a0b  train-32457.jpg -1.000000    False  False  False  False
# 2c21d1119f4b4656  train-32473.jpg  0.506063     True   True  False  False
# c0c8b092b89b8487  train-32486.jpg -1.000000    False  False  False  False
# 484c26b2d0c8c8a0  train-32495.jpg -1.000000    False  False  False  False
# 6ec26078656798c4  train-32497.jpg -1.000000    False  False  False  False
# 0057b7a96b4c1d00  train-32524.jpg -1.000000    False  False  False  False
# 1431d393b1b9b987  train-32565.jpg -1.000000    False  False  False  False
# 163617393d1d3e1c  train-32568.jpg -1.000000    False  False  False  False
# 87cb5565e5b331b9  train-32569.jpg -1.000000    False  False  False  False
# 0901021290b5a5ad  train-32571.jpg  0.341393     True   True  False  False
# fafa6ac2b3f20a84  train-32579.jpg -1.000000    False  False  False  False
# 5ddcdc1e3f1a1db3  train-32589.jpg  0.293767     True   True  False  False
# 2da46665c1c1e52a  train-32602.jpg -1.000000    False  False  False  False
#
#                   police  children  group_20  group_100   flag  night  \
# imageHASH
# 030d92ca8d1f4b6b   False     False      True       True  False   True
# c7c6cecccc6ae6a4   False     False     False      False  False  False
# 94c4c6443cbc9c14   False     False     False      False  False  False
# f2f068703a38e869   False     False     False      False  False  False
# 83a2860706c6e5e4   False     False     False      False  False  False
# 1890151c5859c8f8   False     False     False      False  False  False
# 7f5b59cbdc543c2c   False     False     False      False  False  False
# 97b2d8f4ece0b4c4     False
# 160335f46456562e     False
# bedbdfdede7efe9e     False
# 27658736f5993533     False
# 744b59757515a563     False
# c6c6ae7929a8d463     False
# 7955636367796961     False
# ec6cc6d6a6c7e5c4     False
# 6a22e2626c464360     False
# 43e0144c4c4c4c33     False
# ca61a59cb687c8cd     False
# 6e7e7cdc5d7968b8     False
# b2ed071303870131     False
# d87930353555f061     False
# 68d0981856141cf7     False
# c5466a57ec6e660f     False
# 7864656be2a2260b     False
# a494c469ac8e8ec4     False
# ...                    ...
# 88e8ba7a89b87400     False
# 2125a8ac9cb13b3a     False
# 2e0f77d76b737373     False
# 1e2e2a5d999bd353     False
# ccff26d199193dea     False
# a660746834a361d9     False
# 80d479692c050ccc     False
# 18d94b35312d4520     False
# 4726605a56decde9     False
# 3333b1946b2f475b     False
# 7236cc6c599998e5     False
# 7373391db7723998     False
# d773b9199094ba30     False
# cba3ad29436465a6     False
# f5b6636171929f16     False
# 9c99c9d8163bb125     False
# 484925ab65cdc9eb     False
# 3969cbc7c6da1a0b     False
# 2c21d1119f4b4656     False
# c0c8b092b89b8487     False
# 484c26b2d0c8c8a0     False
# 6ec26078656798c4     False
# 0057b7a96b4c1d00     False
# 1431d393b1b9b987     False
# 163617393d1d3e1c     False
# 87cb5565e5b331b9     False
# 0901021290b5a5ad     False
# fafa6ac2b3f20a84     False
# 5ddcdc1e3f1a1db3     False
# 2da46665c1c1e52a     False
#
# [40720 rows x 13 columns]

# %% [markdown]
# ### Divide the data

# %%
n_folds = 5
seed = 300

# %%
k_folds = au.getKSplitsStratified(df, n_folds, "protest", seed )
for i in k_folds:
    print("kfold has ", len(i[i["protest"] == True]), "protest images and ", len(i[i["protest"] == False]), "non protest images")
# Out:
# kfold has  2329 protest images and  5814 non protest images
# kfold has  2329 protest images and  5814 non protest images
# kfold has  2329 protest images and  5814 non protest images
# kfold has  2329 protest images and  5814 non protest images
# kfold has  2330 protest images and  5818 non protest images

# %%
# print first fold
k_folds[0]
# Out:
#                              name  violence  protest   sign  photo   fire  \
# imageHASH
# 8acce2c3c98dcdc6  train-22845.jpg  0.351009     True   True  False  False
# 87c7ca54d4d21636  train-28103.jpg -1.000000    False  False  False  False
# c4bed6d6d24bd4d0  train-06095.jpg -1.000000    False  False  False  False
# f4f6e666c50c5f55  train-15269.jpg  0.254594     True   True  False  False
# 3ffdf83c39d0e028  train-01764.jpg -1.000000    False  False  False  False
# aaaab9b2b2aaaab0  train-16497.jpg -1.000000    False  False  False  False
# 7070f0e8c6de70b8   test-03345.jpg  0.765545     True  False  False   True
# d992ab5974789b8d  train-07554.jpg -1.000000    False  False  False  False
# 810702e2616b4266  train-01696.jpg  0.288506     True   True  False  False
# 7171694953d9b3bb  train-20588.jpg -1.000000    False  False  False  False
# 9393d1cc4d656b69  train-14657.jpg  0.398108     True   True  False  False
# d1f133b47353dad8  train-03439.jpg -1.000000    False  False  False  False
# ffea4a4e5b2f2cb1  train-28023.jpg -1.000000    False  False  False  False
# 2727717169491e6c  train-29718.jpg -1.000000    False  False  False  False
# 80a6c69207060b09  train-19425.jpg  0.570133     True  False  False   True
# 309049392d29b3b2   test-07614.jpg  0.309640     True   True  False  False
# 88e0f233594c8e55  train-11718.jpg  0.294434     True  False  False  False
# 86943c3a3868d24d   test-07930.jpg -1.000000    False  False  False  False
# cc6cbcc0f8d8c8f9  train-21772.jpg -1.000000    False  False  False  False
# 61632b292b2b0b0b  train-12602.jpg -1.000000    False  False  False  False
# f8d8ccc6e6eae5cc  train-16356.jpg  0.723969     True  False  False   True
# d8c8337cccd2aad0  train-32293.jpg  0.238157     True   True  False  False
# e5edecf5a55cd4a6  train-08663.jpg  0.334919     True   True  False  False
# e8ecc8ec6cfef8da  train-20879.jpg  0.421272     True   True  False  False
# e7e5c485d6fa9594   test-03140.jpg  0.144348     True   True  False  False
# dde4e4a6a6b6f064  train-06555.jpg  0.424349     True   True  False  False
# b83bdaba33399bdb  train-20568.jpg -1.000000    False  False  False  False
# a68881e12f1adb4e   test-02109.jpg  0.282918     True  False  False  False
# 1e120b4d4c467271  train-22317.jpg  0.613322     True   True  False   True
# d0f89cac67a3a5d5  train-14227.jpg  0.399877     True   True  False  False
# ...                           ...       ...      ...    ...    ...    ...
# 1a937f5f5b6b6b67  train-05075.jpg -1.000000    False  False  False  False
# a94dcaf04b139992   test-02210.jpg  0.380431     True   True  False  False
# 994903819d2fae7b  train-24110.jpg -1.000000    False  False  False  False
# 2e28e8d8d4596909  train-00946.jpg -1.000000    False  False  False  False
# 81f86694ac4cc6ae  train-32438.jpg -1.000000    False  False  False  False
# ccb68ab865dffd75  train-18378.jpg  0.280400     True   True  False  False
# ccccb074b2321232  train-19811.jpg -1.000000    False  False  False  False
# fbc7e7afcfd4d8d4  train-18803.jpg -1.000000    False  False  False  False
# 8ce8a420aa2925d8  train-28130.jpg -1.000000    False  False  False  False
# 646464444c6c6060  train-21639.jpg -1.000000    False  False  False  False
# 289ada8aa5999989   test-05207.jpg -1.000000    False  False  False  False
# a9a8d4948c9cf8e4  train-18224.jpg -1.000000    False  False  False  False
# 13306d6c6c5e8779  train-12456.jpg -1.000000    False  False  False  False
# b939b0b0ecf53830  train-07077.jpg  0.237085     True   True  False  False
# 2e3039396c0aacac  train-23804.jpg  0.415064     True   True  False  False
# e1a9ac7666745053  train-02090.jpg -1.000000    False  False  False  False
# f179f1f1b22bd806  train-02202.jpg  0.301822     True   True  False  False
# c0f1b1a53c894e26  train-19661.jpg  0.168988     True   True  False  False
# 6617186f3b2f0627   test-02473.jpg -1.000000    False  False  False  False
# 2495cd8292da9aba  train-03033.jpg -1.000000    False  False  False  False
# 0a0b419239387e3c  train-01307.jpg -1.000000    False  False  False  False
# 20e96034b5f84c0c  train-24663.jpg  0.284672     True   True  False  False
# 464663b2e2c6ca88  train-17670.jpg  0.269354     True   True  False  False
# e8480c09a1a38784  train-32331.jpg  0.365333     True   True  False  False
# e9edafbc9d8d9c6c  train-31976.jpg -1.000000    False  False  False  False
# a6ad63ebd2d6728e  train-10372.jpg -1.000000    False  False  False  False
# 1b333270b929e9f1   test-05631.jpg -1.000000    False  False  False  False
# d9bc26b391cde6b4   test-00698.jpg -1.000000    False  False  False  False
# 1b333270b929e9f1   False     False     False      False  False  False
# d9bc26b391cde6b4   False     False     False      False  False  False
# 4060341a25061309   False     False     False      False  False  False
# c8f3fbfb2509b8a1   False     False      True       True  False  False
#
#                   shouting
# imageHASH
# 8acce2c3c98dcdc6     False
# 87c7ca54d4d21636     False
# c4bed6d6d24bd4d0     False
# f4f6e666c50c5f55     False
# 3ffdf83c39d0e028     False
# aaaab9b2b2aaaab0     False
# 7070f0e8c6de70b8     False
# d992ab5974789b8d     False
# 810702e2616b4266     False
# 7171694953d9b3bb     False
# 9393d1cc4d656b69     False
# d1f133b47353dad8     False
# ffea4a4e5b2f2cb1     False
# 2727717169491e6c     False
# 80a6c69207060b09     False
# 309049392d29b3b2     False
# 88e0f233594c8e55     False
# 86943c3a3868d24d     False
# cc6cbcc0f8d8c8f9     False
# 61632b292b2b0b0b     False
# f8d8ccc6e6eae5cc     False
# d8c8337cccd2aad0     False
# e5edecf5a55cd4a6     False
# e8ecc8ec6cfef8da     False
# e7e5c485d6fa9594     False
# dde4e4a6a6b6f064     False
# b83bdaba33399bdb     False
# a68881e12f1adb4e     False
# 1e120b4d4c467271     False
# d0f89cac67a3a5d5     False
# ...                    ...
# 1a937f5f5b6b6b67     False
# a94dcaf04b139992     False
# 994903819d2fae7b     False
# 2e28e8d8d4596909     False
# 81f86694ac4cc6ae     False
# ccb68ab865dffd75     False
# ccccb074b2321232     False
# fbc7e7afcfd4d8d4     False
# 8ce8a420aa2925d8     False
# 646464444c6c6060     False
# 289ada8aa5999989     False
# a9a8d4948c9cf8e4     False
# 13306d6c6c5e8779     False
# b939b0b0ecf53830     False
# 2e3039396c0aacac     False
# e1a9ac7666745053     False
# f179f1f1b22bd806     False
# c0f1b1a53c894e26     False
# 6617186f3b2f0627     False
# 2495cd8292da9aba     False
# 0a0b419239387e3c     False
# 20e96034b5f84c0c     False
# 464663b2e2c6ca88     False
# e8480c09a1a38784      True
# e9edafbc9d8d9c6c     False
# a6ad63ebd2d6728e     False
# 1b333270b929e9f1     False
# d9bc26b391cde6b4     False
# 4060341a25061309     False
# c8f3fbfb2509b8a1     False
#
# [8143 rows x 13 columns]

# %%
validation_df = k_folds[0].copy()
test_df = k_folds[1].copy()
train_df = k_folds[2].copy().append(k_folds[3].copy()).append(k_folds[4].copy())
print("train set has ", len(train_df) , " images. validation has ", len(validation_df), " images and test has ", len(test_df))
# Out:
# train set has  24434  images. validation has  8143  images and test has  8143

# %%
batch_size = 32

# %%
dummy_test_generator = au.ResizeSequence(
    train_df[np.random.randint(100):np.random.randint(100, 200)],
    batch_size, 
    targets = ['protest', 'violence', tag_cols],
    transforms = [
        lambda img: transforms.randomResizedCrop(img, min_percent=70),
        transforms.randomRotation,
        transforms.randomHorizontalFlip,
        transforms.colorJitter,
        transforms.normalizeMinMax,
        transforms.lighting,
        transforms.normalizeStandardScore
    ] 
)

# %%
first = next(dummy_test_generator.__iter__())
image = first[0][0]
protest = first[1][0]
violence = first[1][1]
img = np.array(image)
plt.imshow(img)
print("protest has shape", protest.shape, " violence has shape", violence.shape)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# protest has shape (32,)  violence has shape (32,)

# %%
mask_value = -1; lr = 0.01; momentum = 0.9; epochs = 100; patience = 10

# %%
hyper_params_name = "momentum-{}_batch_size-{}_n_folds-{}_n_folds_seed-{}".format(momentum, batch_size, n_folds,seed)
hyper_params_name
# Out:
# 'momentum-0.9_batch_size-32_n_folds-5_n_folds_seed-300'

# %%
# COMMENT THIS OUT FOR RUN WITH THE WHOLE DATA SET
# size_sample = 10
# validation_df = validation_df[:34]
# test_df = test_df[:34]
# train_df = train_df[:34]
# epochs = 1
# batch_size = 2
# patience = 0

# %%
train_generator = au.ResizeSequence(
    train_df,
    batch_size, 
    targets = ['protest', 'violence', tag_cols],
    transforms = [
        lambda img: transforms.randomResizedCrop(img, min_percent=70),
        transforms.randomRotation,
        transforms.randomHorizontalFlip,
        transforms.colorJitter,
        transforms.normalizeMinMax,
        transforms.lighting,
        transforms.normalizeStandardScore
    ]
)
validation_generator = au.ResizeSequence(
    validation_df,
    batch_size, 
    targets = ['protest', 'violence', tag_cols],
    transforms = [
        transforms.resize,
        transforms.centerCrop,
        transforms.normalizeMinMax,
        transforms.normalizeStandardScore
    ]
)

test_generator = au.ResizeSequence(
test_df,
batch_size, 
targets = ['protest', 'violence', tag_cols],
transforms = [
    transforms.resize,
    transforms.centerCrop,
    transforms.normalizeMinMax,
    transforms.normalizeStandardScore
]
)



# Modeling start
Kbackend.clear_session()

img_input = Klayers.Input(shape=(224,224,3), name='img_input')

resnet_model = Kapplications.ResNet50(include_top=False, weights = 'imagenet') (img_input)

flatten = Klayers.Flatten()(resnet_model)

fully_connected_violence = Klayers.Dense(1000, activation='relu')(flatten)
dropout_violence = Klayers.Dropout(.5)(fully_connected_violence)
violence_out = Klayers.Dense(1, activation='sigmoid', name='violence_out')(dropout_violence)


fully_connected_protest = Klayers.Dense(1000, activation= 'relu') (flatten)
dropout_protest = Klayers.Dropout(.5) (fully_connected_protest)
protest_out = Klayers.Dense(1, activation='sigmoid', name='protest_out')(dropout_protest)

fully_connected_visuals = Klayers.Dense(1000, activation= 'relu') (flatten)
dropout_visuals = Klayers.Dropout(.5)(fully_connected_visuals)
visual_out = Klayers.Dense(10, activation='sigmoid', name='visual_out')(dropout_visuals)

model = Kmodels.Model(inputs= img_input, outputs=[protest_out, violence_out, visual_out])

optimizer = Koptimizers.SGD(lr=lr, momentum=momentum, nesterov=False)
model.compile(
    optimizer=optimizer,
    loss={
        'protest_out': Klosses.binary_crossentropy,
        'violence_out': au.buildMaskedLoss(Klosses.mean_squared_error, mask_value),
        'visual_out': au.buildMaskedLoss(Klosses.binary_crossentropy, mask_value), 
    },
    loss_weights={
        'protest_out': 1., 
        'violence_out': 10,
        'visual_out': 5,
    }
)
model.summary()

try:
    __file__ # Apparently, this is not defined in the notebook,
         # but it will be when we start running on the server
         # (So when things gets real)
except NameError:
    __file__ = "test"


name = au.getExperimentName(__file__, len(df), epochs, lr, hyper_params_name)
csv_results = "models_preds/%s.csv" % name
model_checkout_path = "models/%s.hdf5" % name
csv_logger_path = "logs/%s.csv" % name
tensor_board_folder = os.path.join("logs", name)

if not os.path.exists(tensor_board_folder):
    os.makedirs(tensor_board_folder)

if not os.path.exists(tensor_board_folder):
    os.makedirs("logs")

if not os.path.exists(tensor_board_folder):
    os.makedirs("models")

if not os.path.exists(tensor_board_folder):
    os.makedirs("models_preds")

print("Writing model to: \t%s" % model_checkout_path)
print("Writing log to: \t%s\n" % csv_logger_path)



# callbacks
change_lr = Kcallbacks.LearningRateScheduler(
    au.lrUpdateUCLA, 
    verbose = True
)

checkpoint = Kcallbacks.ModelCheckpoint(
    model_checkout_path,
    monitor='val_loss', 
    verbose=1,
    save_best_only=True,
    save_weights_only=False,
    mode='auto',
    period=1
)

earlystop = Kcallbacks.EarlyStopping(
    monitor='val_loss',
    min_delta=0, 
    patience=patience,
    verbose=1, 
    mode='auto'
)

tensor_board = Kcallbacks.TensorBoard(
    log_dir=tensor_board_folder,
     histogram_freq=0,
     batch_size=32, 
     write_graph=True,
     write_grads=False, 
     write_images=False, 
     embeddings_freq=0,
     embeddings_layer_names=None,
     embeddings_metadata=None
)

csv_logger = Kcallbacks.CSVLogger(
    csv_logger_path, 
    separator=',', 
    append=False
)

history = model.fit_generator(
    train_generator,
    validation_data= validation_generator,
    epochs=epochs,
    callbacks = [change_lr, checkpoint, tensor_board, csv_logger, earlystop]
)


# Preds

#load the weights from the best model
model.load_weights(model_checkout_path)

preds = model.predict_generator(test_generator, verbose = 1)
preds_protest = preds[0][:len(test_df)] # avoid getting more than the needed
preds_violence = preds[1][:len(test_df)] 
preds_visuals = preds[2][:len(test_df)] 
print("protest shape is ", preds_protest.shape, " violence shape is ", preds_violence.shape, "visual shape is ", preds_visuals.shape)
# Creates a panda data frame with the results

test_fold_results = test_df.copy()
test_fold_results["pred_protest"] = preds_protest
test_fold_results["pred_violence"] = preds_violence
for i, tc in enumerate(tag_cols):
    pred_tc = "pred_%s" % tc
    test_fold_results[pred_tc] = preds_visuals[:,i]

print("saving results")
test_fold_results.to_csv(csv_results)
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# img_input (InputLayer)          (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# resnet50 (Model)                multiple             23587712    img_input[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 2048)         0           resnet50[1][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1000)         2049000     flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1000)         2049000     flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1000)         2049000     flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 1000)         0           dense_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1000)         0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 1000)         0           dense_3[0][0]
# __________________________________________________________________________________________________
# protest_out (Dense)             (None, 1)            1001        dropout_2[0][0]
# __________________________________________________________________________________________________
# violence_out (Dense)            (None, 1)            1001        dropout_1[0][0]
# __________________________________________________________________________________________________
# visual_out (Dense)              (None, 10)           10010       dropout_3[0][0]
# ==================================================================================================
# Total params: 29,746,724
# Trainable params: 29,693,604
# Non-trainable params: 53,120
# __________________________________________________________________________________________________
# Writing model to: 	models/test_datalen-40720_epochs-1_init_lr-0.01_momentum-0.9_batch_size-32_n_folds-5_n_folds_seed-300.hdf5
# Writing log to: 	logs/test_datalen-40720_epochs-1_init_lr-0.01_momentum-0.9_batch_size-32_n_folds-5_n_folds_seed-300.csv
#
# WARNING:tensorflow:From /home/jesper/.local/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/base.py:198: retry (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the retry module or similar alternatives.
# Epoch 1/1
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009999999776482582.
# 17/17 [==============================] - 70s 4s/step - loss: 6.5500 - protest_out_loss: 1.8982 - violence_out_loss: 0.0847 - visual_out_loss: 0.7610 - val_loss: 26.3257 - val_protest_out_loss: 7.0334 - val_violence_out_loss: 0.0982 - val_visual_out_loss: 3.6620
#
# Epoch 00001: val_loss improved from inf to 26.32575, saving model to models/test_datalen-40720_epochs-1_init_lr-0.01_momentum-0.9_batch_size-32_n_folds-5_n_folds_seed-300.hdf5
# 17/17 [==============================] - 16s 953ms/step
# protest shape is  (34, 1)  violence shape is  (34, 1) visual shape is  (34, 10)
# saving results
